# %%
import wandb
from wandb.keras import WandbCallback
wandb.init(project="calhack6-0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c619387e9256> in <module>
#       1 import wandb
# ----> 2 from wandb.keras import WandbCallback
#       3 wandb.init(project="calhack6-0")
#
# c:\users\bp\appdata\local\programs\python\python37\lib\site-packages\wandb\keras\__init__.py in <module>
#      13     import keras.backend as K
#      14 elif "tensorflow.python.keras" in sys.modules:
# ---> 15     import tensorflow.keras as keras
#      16     import tensorflow.keras.backend as K
#      17 else:
#
# c:\users\bp\appdata\local\programs\python\python37\lib\site-packages\tensorflow\__init__.py in <module>
#      33 from tensorflow._api.v1 import autograph
#      34 from tensorflow._api.v1 import bitwise
# ---> 35 from tensorflow._api.v1 import compat
#      36 from tensorflow._api.v1 import config
#      37 from tensorflow._api.v1 import data
#
# ...

# %%
model.fit(X_train, y_train, validationData=(X_test, y_test)
   epochs=config.epochs, callbacks=[WandbCallback()])
